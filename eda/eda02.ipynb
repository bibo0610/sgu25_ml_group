# %% [markdown]
# # Challenge 2: House Prices - Advanced Regression Techniques

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open("House.jpg")

# %% [markdown]
# ## 1. Định nghĩa vấn đề (Define Problem)
# + **Mô tả**:
#     + Bộ dữ liệu House Prices gồm 80 biến mô tả gần như mọi khía cạnh của các ngôi nhà tại Ames, Iowa. Mục tiêu của bài toán là dự đoán giá bán cuối cùng của từng ngôi nhà dựa trên những đặc trưng về kiến trúc, diện tích, vật liệu, tiện ích, vị trí và các yếu tố khác.
#     + Đây là một bài toán hồi quy (regression) trong học máy.
# + **Dữ liệu vào**:
#     + MSSubClass: Loại nhà / kiểu xây dựng.
#     + MSZoning: Phân loại khu vực đất.
#     + LotFrontage: Chiều dài mặt tiền lô đất tiếp giáp đường.
#     + LotArea: Diện tích lô đất.
#     + Street: Loại đường vào nhà.
#     + Alley: Loại hẻm vào nhà.
#     + LotShape: Hình dạng lô đất.
#     + LandContour: Độ bằng phẳng của đất.
#     + Utilities: Loại tiện ích có sẵn (điện, nước…).
#     + LotConfig: Cách bố trí lô đất.
#     + LandSlope: Độ dốc của lô đất.
#     + Neighborhood: Khu vực / vùng trong thành phố Ames
#     + Condition1: Gần đường lớn hoặc đường sắt.
#     + Condition2: Gần đường lớn hoặc đường sắt (nếu có thêm điều kiện thứ hai).
#     + BldgType: Loại nhà ở.
#     + HouseStyle: Phong cách nhà.
#     + OverallQual: Chất lượng tổng thể của vật liệu và hoàn thiện.
#     + OverallCond: Tình trạng tổng thể của nhà.
#     + YearBuilt: Năm xây dựng nhà.
#     + YearRemodAdd: Năm cải tạo nhà.
#     + RoofStyle: Kiểu mái nhà.
#     + RoofMatl: Vật liệu lợp mái.
#     + Exterior1st: Vật liệu ốp bên ngoài chính.
#     + Exterior2nd: Vật liệu ốp bên ngoài phụ (nếu có nhiều loại).
#     + MasVnrType: Loại ốp tường bằng gạch/masonry.
#     + MasVnrArea: Diện tích ốp tường.
#     + ExterQual: Chất lượng vật liệu bên ngoài.
#     + ExterCond: Tình trạng bên ngoài hiện tại.
#     + Foundation: Loại nền móng.
#     + BsmtQual: Chiều cao tầng hầm.
#     + BsmtCond: Tình trạng tầng hầm.
#     + BsmtExposure: Tầng hầm có cửa ra ngoài hay cửa sổ không.
#     + BsmtFinType1: Chất lượng phần hoàn thiện tầng hầm 1.
#     + BsmtFinSF1: Diện tích hoàn thiện tầng hầm 1.
#     + BsmtFinType2: Chất lượng phần hoàn thiện tầng hầm 2.
#     + BsmtFinSF2: Diện tích hoàn thiện tầng hầm 2.
#     + BsmtUnfSF: Diện tích tầng hầm chưa hoàn thiện.
#     + TotalBsmtSF: Tổng diện tích tầng hầm.
#     + Heating: Loại hệ thống sưởi
#     + HeatingQC: Chất lượng hệ thống sưởi.
#     + CentralAir: Có điều hòa trung tâm không.
#     + Electrical: Hệ thống điện.
#     + 1stFlrSF: Diện tích tầng 1.
#     + 2ndFlrSF: Diện tích tầng 2.
#     + LowQualFinSF: Diện tích hoàn thiện chất lượng thấp.
#     + GrLivArea: Diện tích sử dụng trên mặt đất.
#     + BsmtFullBath: Số phòng tắm đầy đủ ở tầng hầm.
#     + BsmtHalfBath: Số phòng tắm nửa ở tầng hầm.
#     + FullBath: Số phòng tắm đầy đủ trên tầng chính.
#     + HalfBath: Số phòng tắm nửa trên tầng chính.
#     + Bedroom: Số phòng ngủ trên tầng chính.
#     + Kitchen: Số bếp.
#     + KitchenQual: Chất lượng bếp.
#     + TotRmsAbvGrd: Tổng số phòng trên tầng chính (không tính phòng tắm).
#     + Functional: Tình trạng sử dụng của nhà (có tiện dụng không).
#     + Fireplaces: Số lò sưởi.
#     + FireplaceQu: Chất lượng lò sưởi.
#     + GarageType: Vị trí gara.
#     + GarageYrBlt: Năm xây dựng gara.
#     + GarageFinish: Hoàn thiện nội thất gara.
#     + GarageCars: Sức chứa ô tô trong gara.
#     + GarageArea: Diện tích gara.
#     + GarageQual: Chất lượng gara.
#     + GarageCond: Tình trạng gara.
#     + PavedDrive: Đường lái xe lát.
#     + WoodDeckSF: Diện tích sàn gỗ ngoài trời.
#     + OpenPorchSF: Diện tích hiên mở.
#     + EnclosedPorch: Diện tích hiên kín.
#     + 3SsnPorch: Diện tích hiên 3 mùa.
#     + ScreenPorch: Diện tích hiên có lưới.
#     + PoolArea: Diện tích hồ bơi.
#     + PoolQC: Chất lượng hồ bơi.
#     + Fence: Chất lượng hàng rào.
#     + MiscFeature: Các tiện ích khác.
#     + MiscVal: Giá trị tiền của tiện ích khác.
#     + MoSold: Tháng bán.
#     + YrSold: Năm bán.
#     + SaleType: Hình thức bán.
#     + SaleCondition: Tình trạng bán.
#
# + **Kết quả**: SalePrice: Giá bán bất động sản (USD) - Biến mục tiêu (Target Variable):
#     + Giá trị thực tế của ngôi nhà, tính bằng đô la Mỹ (USD)
#     + Là biến liên tục, dùng cho bài toán hồi quy (Regression)

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.imshow(image.resize((600, 400)))
ax.axis("off")
ax.set_title("Houses", fontsize=14, pad=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Chuẩn bị vấn đề (Prepare Problem)

# %% [markdown]
# ### 2.1. Khai báo thư viện (Load Libraries)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display

import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.2. Nạp dữ liệu (Load Dataset)

# %%
# Load dataset
df_train = pd.read_csv("../../data02/train.csv")
df_test = pd.read_csv("../../data02/test.csv")

# %% [markdown]
# ## 3. Phân tích khám phá dữ liệu (Exploration Analyze Data - EDA)

# %% [markdown]
# ### 3.1. Thống kê mô tả (Descriptive Statistics) - Ungraphic Approach

# %% [markdown]
# #### (1) **Hiển thị một số thông tin về dữ liệu**

# %%
# shape
print(f'+ Shape: {df_train.shape}')
# head, tail
print(f'+ Contents: ')
display.display(df_train.head(5))
display.display(df_train.tail(5))
# info
df_train.info()
# Out:
# + Shape: (1460, 81)
# + Contents:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
# ...

# %% [markdown]
# **Nhận xét:**
# - Tổng số dòng dữ liệu là 1460
# - Dữ liệu dùng để phân lớp ở cột SalePrice

# %% [markdown]
# #### (2) **Kiểm tra tính toàn vẹn của dữ liệu**

# %%
# Kiểm tra giá trị thiếu
def isNull(df):
    print("="*5, "Checking Null", "="*5)
    null_counts = df.isnull().sum()
    null_cols = null_counts[null_counts > 0]
    if len(null_cols) > 0 :
        display.display(null_cols)
    has_null = df.isnull().sum().any()
    print(f'--> Có giá trị Null: {has_null}')

# %%
isNull(df_train)
# Out:
# ===== Checking Null =====
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
# --> Có giá trị Null: True

# %%
isNull(df_test)
# Out:
# ===== Checking Null =====
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType       894
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64
# --> Có giá trị Null: True

# %% [markdown]
# **Nhận xét:**
# - Dữ liệu ở tập train có giá trị thiếu ở cột LotFrontage (259), Alley (1369), MasVnrType (872), MasVnrArea (8), BsmtQual (37), BsmtCond (37), BsmtExposure (38), BsmtFinType1 (37), BsmtFinType2 (38), Electrical (1), FireplaceQu (690), GarageType (81), GarageYrBlt (81), GarageFinish (81), GarageQual (81), GarageCond (81), PoolQC (1453), Fence (1179), MiscFeature (1406).
#
# - Dữ liệu ở tập test có giá trị thiếu ở cột MSZoning (4), LotFrontage (227), Alley (1352), Utilities (2),Exterior1st (1),
# Exterior2nd (1), MasVnrType (894), MasVnrArea (15), BsmtQual (44), BsmtCond (45), BsmtExposure(44), BsmtFinType1 (42), BsmtFinSF1 (1), BsmtFinType2 (42), BsmtFinSF2 (1), BsmtUnfSF (1), TotalBsmtSF (1), BsmtFullBath (2), BsmtHalfBath (2), KitchenQual (1), Functional (2), FireplaceQu (730), GarageType (76), GarageYrBlt (78), GarageFinish (78), GarageCars (1), GarageArea (1), GarageQual (78), GarageCond (78), PoolQC (1456), Fence (1169), MiscFeature (1408), SaleType (1).

# %% [markdown]
# #### (3) **Các tính chất thống kê trên dữ liệu số**
#
# + Count, Mean, Standard Deviation, Minimum Value
# + 25th Percentile, 50th Percentile (Median), 75th Percentile, Maximum Value

# %%
display.display(df_train.describe().T)
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %% [markdown]
# **Nhận xét**
# - Bảng kết quả thống kê mô tả cho thấy hầu hết các biến như OverallQual, OverallCond, FullBath, BedroomAbvGr, GarageCars có giá trị trung bình và độ lệch chuẩn nhỏ, thể hiện sự ổn định giữa các quan sát. Ngược lại, các biến về diện tích và kích thước như LotArea, GrLivArea, TotalBsmtSF, 1stFlrSF có độ lệch chuẩn rất cao, cho thấy phân bố lệch phải và tồn tại nhiều giá trị ngoại lệ. Một số cột có giá trị thiếu như LotFrontage, MasVnrArea, GarageYrBlt cần được xử lý trước khi phân tích sâu hơn. Ngoài ra, nhiều biến có giá trị trung vị bằng 0 (như PoolArea, 3SsnPorch, ScreenPorch) cho thấy phần lớn các căn nhà không có các tiện ích này.
# - Biến mục tiêu SalePrice có trung bình khoảng 180,921 USD, độ lệch chuẩn lớn (~79,000 USD), thể hiện sự chênh lệch đáng kể về giá giữa các căn nhà.

# %% [markdown]
# #### (4) **Tần số xuất hiện (Distribution) trên dữ liệu phân lớp (Class) và dữ liệu danh mục (Category)**

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# Biểu đồ phân phối (histogram + kde)
sns.histplot(df_train['SalePrice'], bins=30, kde=True, color='#66b3ff', ax=ax[0])
ax[0].set_title('Phân bố giá nhà (SalePrice)', fontsize=12)
ax[0].set_xlabel('Giá nhà')
ax[0].set_ylabel('Tần suất')

# Biểu đồ Boxplot
sns.boxplot(x=df_train['SalePrice'], color='#ff9999', ax=ax[1])
ax[1].set_title('Boxplot giá nhà (SalePrice)', fontsize=12)
ax[1].set_xlabel('Giá nhà')

plt.suptitle('Phân bố biến mục tiêu (SalePrice)', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Nhận xét**
# - Biểu đồ histogram và boxplot cho biến SalePrice cho thấy giá nhà trong tập dữ liệu có phân bố lệch phải (right-skewed) — phần lớn các căn nhà có giá nằm trong khoảng 100.000–250.000 USD, trong khi một số ít căn có giá rất cao kéo dài về phía bên phải. Đường mật độ (KDE) không đối xứng, đỉnh tập trung ở vùng giá trung bình thấp.
# - Biểu đồ boxplot cũng thể hiện rõ sự tồn tại của nhiều giá trị ngoại lệ (outliers) với giá nhà vượt xa mức trung bình -> dữ liệu giá nhà không tuân theo phân phối chuẩn.

# %%
# Đếm tần suất giá trị trong từng cột dạng chữ
cat_cols = df_train.select_dtypes(include=['object']).columns.tolist()

for col in cat_cols:
    print(f"--- {col} ---")
    print(df_train[col].value_counts(), "\n")
# Out:
# --- MSZoning ---
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
# --- Street ---
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
#
# --- Alley ---
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
#
# --- LotShape ---
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
#
# --- LandContour ---
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
#
# --- Utilities ---
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
#
# --- LotConfig ---
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
#
# --- LandSlope ---
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
#
# --- Neighborhood ---
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# ...

# %% [markdown]
# **Nhận xét**
#
# Các biến dạng chữ (categorical features) trong tập dữ liệu có mức độ phân bố giá trị khá chênh lệch giữa các cột. Một số biến thể hiện sự thiên lệch mạnh về một nhóm giá trị nhất định, ví dụ:
#
# Utilities, RoofMatl, Heating, Condition2, Functional có hơn 95% giá trị tập trung ở một nhãn duy nhất → không mang nhiều thông tin phân biệt, có thể xem xét loại bỏ khỏi mô hình.
#
# Các biến như MSZoning, Street, LandSlope, CentralAir, PavedDrive cũng có sự mất cân đối rõ rệt nhưng vẫn thể hiện được đặc điểm khu vực và cơ sở hạ tầng nên vẫn hữu ích cho phân tích.
#
# Một số biến quan trọng như Neighborhood, Exterior1st, Exterior2nd, Foundation, BldgType, HouseStyle có đa dạng giá trị cao, phản ánh đặc điểm kiến trúc và vị trí nhà ở — thường có ảnh hưởng mạnh đến giá nhà (SalePrice).
#
# Ngoài ra, nhiều biến như Alley, Fence, PoolQC, MiscFeature có ít giá trị hợp lệ, thể hiện nhiều giá trị khuyết thiếu, nên cần xử lý cẩn thận trước khi huấn luyện mô hình.

# %%
# Xác định cột số và cột phân loại
numeric_cols = df_train.select_dtypes(include=['int64', 'float64']).columns.drop('SalePrice')
categorical_cols = df_train.select_dtypes(include=['object']).columns

print("Cột số:", len(numeric_cols))
print(numeric_cols.tolist())

print("\nCột phân loại:", len(categorical_cols))
print(categorical_cols.tolist())
# Out:
# Cột số: 37
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
#
# Cột phân loại: 43
# ...

# %% [markdown]
# **Nhận xét**
#
# Tập dữ liệu gồm 37 cột số và 43 cột phân loại.
#
# Các cột số bao gồm nhiều thông tin định lượng về diện tích, năm xây dựng, số phòng, tiện ích, diện tích hầm, diện tích sàn, số tầng, v.v. — đây là nhóm có ảnh hưởng trực tiếp đến giá nhà.
#
# Các cột phân loại mô tả đặc điểm định tính như khu vực (Neighborhood), loại nhà (HouseStyle, BldgType), vật liệu xây dựng (Exterior1st, RoofMatl), chất lượng (KitchenQual, ExterQual) và nhiều yếu tố khác. Những biến này thường có ảnh hưởng gián tiếp nhưng đáng kể đến giá trị nhà ở.
#
# Dữ liệu cân bằng tốt giữa thông tin định lượng và định tính, phù hợp cho việc xây dựng mô hình hồi quy đa biến hoặc mô hình học máy phi tuyến như Random Forest, XGBoost.

# %% [markdown]
# # Trực quan hóa dữ liệu

# %% [markdown]
# ### Phân bố từng thuộc tính

# %%
for cols in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(x=cols, data=df_train)
    plt.title(f"Phân bố của {cols}")
    plt.show()

# %% [markdown]
# **Nhận xét**
#
# Nhiều biến như LotArea, GrLivArea, TotalBsmtSF có phân bố lệch phải mạnh, cho thấy phần lớn các căn nhà có diện tích nhỏ hoặc trung bình, trong khi chỉ có một số ít có diện tích rất lớn (các outliers tiềm năng).
#
# Một số biến rời rạc như OverallQual, OverallCond, BsmtFullBath, FullBath, HalfBath, Fireplaces, GarageCars có phân bố dạng bậc (discrete) – đặc trưng cho dữ liệu đếm hoặc đánh giá mức độ.
#
# Các biến liên quan đến năm như YearBuilt, YearRemodAdd, YrSold có xu hướng tăng dần theo thời gian, phản ánh sự phát triển của khu dân cư.
#
# Một số biến như LotFrontage, PoolArea, MiscVal chứa nhiều giá trị bằng 0 hoặc thiếu, cho thấy khả năng dữ liệu trống hoặc không phổ biến (ví dụ ít nhà có hồ bơi hoặc giá trị phụ thêm).

# %%
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=df_train, order=df_train[col].value_counts().index)
    plt.title(f'Phân bố của {col}', fontsize=12, fontweight='bold')
    
    # Nếu có quá nhiều giá trị thì xoay nhãn
    if df_train[col].nunique() > 5:
        plt.xticks(rotation=45, ha='right')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Nhận xét**
#
# Nhiều biến có phân bố mất cân bằng rõ rệt, trong đó một vài giá trị chiếm đa số, ví dụ:
#
# Utilities, RoofMatl, Heating, Functional, Condition2 gần như chỉ có 1 giá trị chiếm áp đảo → thông tin hạn chế, có thể xem xét loại bỏ.
#
# CentralAir và Street cũng có sự thiên lệch lớn (đa số là "Y" hoặc "Pave").
#
# Một số biến như Neighborhood, Exterior1st, Exterior2nd, Foundation, HouseStyle, BldgType có phân bố đa dạng hơn, thể hiện rõ sự khác biệt về khu vực và kiểu nhà – đây là những biến có khả năng ảnh hưởng mạnh đến giá nhà.
#
# Một số cột như Alley, PoolQC, Fence, MiscFeature có ít giá trị hợp lệ, số lượng mẫu thuộc từng nhóm nhỏ → cần xử lý giá trị thiếu hoặc gộp nhóm để tránh nhiễu khi mô hình hóa.

# %% [markdown]
# ### Trực quan hóa theo biến mục tiêu

# %%
# Tạo biến mục tiêu phân loại (chia SalePrice thành 3 nhóm)
df_train['PriceRange'] = pd.qcut(df_train['SalePrice'], q=3, labels=['Thấp', 'Trung bình', 'Cao'])

# Biểu đồ countplot theo biến mục tiêu
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=col, hue='PriceRange', data=df_train)
    plt.title(f'Phân bố {col} theo nhóm giá nhà (SalePrice)')
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Nhóm giá')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Nhận xét**
#
# Một số biến có sự khác biệt rõ rệt giữa các nhóm giá, chứng tỏ mức độ ảnh hưởng mạnh đến SalePrice, ví dụ:
#
# Neighborhood: các khu như NoRidge, StoneBr, NridgHt tập trung nhiều ở nhóm giá cao, trong khi OldTown, Edwards, IDOTRR chủ yếu thuộc nhóm thấp.
#
# HouseStyle, BldgType, Exterior1st, KitchenQual, ExterQual cũng thể hiện rõ xu hướng — những loại nhà hoặc vật liệu chất lượng tốt thường xuất hiện ở nhóm giá cao.
#
# Một số biến như RoofMatl, Heating, Utilities có phân bố tương đối giống nhau giữa các nhóm giá → ít ảnh hưởng đến giá nhà.
#
# Các biến có nhiều giá trị hiếm như PoolQC, Fence, MiscFeature cho thấy dữ liệu phân bố không đều, khó rút ra kết luận đáng tin cậy.

# %% [markdown]
# ### Tương quan giữa các biến số với SalePrice

# %%
corr = df_train.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap='coolwarm', center=0)
plt.title('Ma trận tương quan giữa các biến số')
plt.show()

# Top 10 biến tương quan mạnh nhất với SalePrice
corr_target = corr['SalePrice'].sort_values(ascending=False)
print("Top 10 biến tương quan mạnh nhất với SalePrice:")
print(corr_target.head(10))
# Out:
# Top 10 biến tương quan mạnh nhất với SalePrice:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %% [markdown]
# **Nhận xét**
#
# OverallQual có tương quan cao nhất với SalePrice (≈ 0.79) → chất lượng tổng thể của ngôi nhà là yếu tố ảnh hưởng lớn nhất đến giá.
#
# Các biến như GrLivArea (diện tích sàn sinh hoạt), GarageCars, GarageArea, TotalBsmtSF, và 1stFlrSF đều có hệ số tương quan trên 0.6, cho thấy diện tích và quy mô không gian sử dụng đóng vai trò rất quan trọng trong việc định giá nhà.
#
# Các biến FullBath, TotRmsAbvGrd, và YearBuilt cũng có tương quan dương đáng kể (trên 0.5), phản ánh rằng nhà mới hơn, nhiều phòng hơn, và có nhiều tiện nghi hơn thường có giá cao hơn.
#
# Ngược lại, phần lớn các biến còn lại có tương quan thấp → tác động yếu đến giá nhà hoặc mang tính gián tiếp.
#
# -> Tổng kết: Giá nhà chịu ảnh hưởng mạnh bởi chất lượng xây dựng (OverallQual) và quy mô diện tích (GrLivArea, GarageArea, TotalBsmtSF). Đây là những biến quan trọng cần được ưu tiên khi xây dựng mô hình dự đoán SalePrice.

# %% [markdown]
# ### Phát hiện giá trị ngoại lai (Outlier)

# %%
top_corr_features = corr_target.index[1:6]
for col in top_corr_features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df_train[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# **Nhận xét**
# - OverallQual có tương quan mạnh nhất với SalePrice. Khi chất lượng nhà tăng thì giá nhà cũng tăng  -> đây là biến dự báo rất quan trọng
# - GrLivArea giá bán sẽ tăng theo diện tích đất sử dụng
# - GarageCars và GarageArea cùng thể hiện khả năng chứa xe của ngôi nhà -> ảnh hưởng khá cao đến giá nhà
# - TotalBsmtSF: tổng diện tích tầng hầm cũng có khả năng ảnh hưởng khá cao đến giá nhà vì độ tương quan khá cao (0.613581)

# %% [markdown]
# ## 4. Kết luận & Insight
#
# - Các biến ảnh hưởng mạnh nhất đến giá nhà: `OverallQual`, `GrLivArea`, `GarageCars`, `GarageArea`, `TotalBsmtSF`.
# - `SalePrice` bị lệch phải → nên log-transform để mô hình dự đoán tốt hơn.
# - Một số biến có nhiều missing values (`PoolQC`, `Alley`, `Fence`, `MiscFeature`) → cần xử lý.
# - Một số outlier ở `GrLivArea > 4000` nên xem xét loại bỏ.
